# %% [markdown]
# <a href="https://colab.research.google.com/github/Devansharma/Data_Extration_using_images/blob/master/OCR_Extracting_Information.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install easyocr

# %%
# !wget https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.accountingcoach.com%2Ffinancial-ratios%2Fexplanation%2F3&psig=AOvVaw1GXQExv3fQPunf8uFiUyqs&ust=1597728160101000&source=images&cd=vfe&ved=0CAIQjRxqFwoTCJDY1K2_oesCFQAAAAAdAAAAABAD
# Out:
# --2020-08-17 05:33:14--  https://www.google.com/url?sa=i
# Resolving www.google.com (www.google.com)... 173.194.76.104, 173.194.76.147, 173.194.76.106, ...
# Connecting to www.google.com (www.google.com)|173.194.76.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘url?sa=i’
#
# url?sa=i                [ <=>                ]   1.37K  --.-KB/s    in 0s
#
# 2020-08-17 05:33:15 (16.1 MB/s) - ‘url?sa=i’ saved [1401]

# %%
import easyocr
reader = easyocr.Reader(['en'])

# %%
import PIL
from PIL import ImageDraw
im = PIL.Image.open('image.jpg')
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=487x703 at 0x7F41A11BEE10>

# %%
bounds = reader.readtext('image.jpg')
bounds
# Out:
# [([[139, 5], [349, 5], [349, 25], [139, 25]],
#   'Innovative Products, Inc.',
#   0.1575341522693634),
#  ([[162, 28], [324, 28], [324, 52], [162, 52]],
#   'Income Statement',
#   0.7829012870788574),
#  ([[94, 51], [392, 51], [392, 82], [94, 82]],
#   'For Year Ending December31,2012',
#   0.6812752485275269),
#  ([[0, 106], [50, 106], [50, 130], [0, 130]], 'Sales', 0.7557392120361328),
#  ([[378, 106], [480, 106], [480, 132], [378, 132]],
#   '$50,00,000',
#   0.19709427654743195),
#  ([[13, 135], [171, 135], [171, 155], [13, 155]],
#   'Cost of Goods Sold',
#   0.10680961608886719),
#  ([[288, 160], [368, 160], [368, 184], [288, 184]],
#   '8,00,000',
#   0.9397319555282593),
#  ([[31, 161], [111, 161], [111, 181], [31, 181]],
#   'Materials',
#   0.9946557879447937),
#  ([[278, 186], [368, 186], [368, 210], [278, 210]],
#   '11,00,000',
#   0.90208500623703),
#  ([[29, 187], [81, 187], [81, 207], [29, 207]], 'Labor', 0.9946473836898804),
# ...

# %%
def draw_boxes(image, bounds, color='red', width=2):
  draw = ImageDraw.Draw(image)
  for bound in bounds:
    p0, p1, p2, p3 = bound[0]
    draw.line([*p0, *p1, *p2, *p3,*p0], fill = color, width=width)
  return image

draw_boxes(im, bounds)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=487x703 at 0x7F41A11BEE10>

# %%
bounds = reader.readtext('image.jpg', contrast_ths = 0.05, adjust_contrast=0.7, 
                         add_margin=0.45, width_ths=0.7, decoder='beamsearch')
bounds
# Out:
# [([[132, 0], [356, 0], [356, 32], [132, 32]],
#   'Innovative Products, Inc.',
#   0.797170877456665),
#  ([[155, 21], [331, 21], [331, 59], [155, 59]],
#   'Income Statement',
#   0.753039538860321),
#  ([[84, 41], [402, 41], [402, 92], [84, 92]],
#   'For Vear Ending December31,2O12',
#   0.13891282677650452),
#  ([[0, 99], [57, 99], [57, 137], [0, 137]], 'Sales', 0.7219205498695374),
#  ([[371, 99], [487, 99], [487, 139], [371, 139]],
#   '$$50,00,000',
#   0.2813180685043335),
#  ([[6, 128], [178, 128], [178, 162], [6, 162]],
#   'Cost of Goods Sold',
#   0.47714197635650635),
#  ([[281, 153], [375, 153], [375, 191], [281, 191]],
#   '8,00,000',
#   0.2115696519613266),
#  ([[24, 154], [118, 154], [118, 188], [24, 188]],
#   'Materials',
#   0.7366260886192322),
#  ([[271, 179], [375, 179], [375, 217], [271, 217]],
#   '1,00,000',
#   0.4486844539642334),
#  ([[22, 180], [88, 180], [88, 214], [22, 214]], 'Labor', 0.9856516122817993),
# ...

# %%
draw_boxes(im, bounds)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=487x703 at 0x7F41A11BEE10>
